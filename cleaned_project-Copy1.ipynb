# %%
import pandas as pd
import numpy as np

# %%
loc='data.xls'
in_df=pd.read_excel(loc)
in_df.head()
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  ...  \
# 0                   0.881686         0.517637  ...
# 1                   0.850035         0.583926  ...
# 2                   0.706766         0.618265  ...
# 3                   0.731109         0.611387  ...
# 4                   0.775620         0.710385  ...
#
#    GINI index (World Bank estimate)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    GINI index (World Bank estimate), average 2000-16  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    gini of household income reported in Gallup, by wp5-year  \
# 0                                                NaN
# 1                                           0.441906
# 2                                           0.327318
# 3                                           0.336764
# 4                                           0.344540
#
#    Most people can be trusted, Gallup  \
# 0                                 NaN
# 1                            0.286315
# 2                            0.275833
# 3                                 NaN
# 4                                 NaN
#
#    Most people can be trusted, WVS round 1981-1984  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1989-1993  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1994-1998  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1999-2004  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2005-2009  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2010-2014
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
# [5 rows x 26 columns]

# %%
in_df.columns.values
# Out:
# array(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-16',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
#        'Most people can be trusted, WVS round 2005-2009',
#        'Most people can be trusted, WVS round 2010-2014'], dtype=object)

# %%
in_df.drop('GINI index (World Bank estimate)', axis=1, inplace=True)

# %%
df=in_df.drop('Most people can be trusted, Gallup', axis=1, inplace=True)

# %%
df=in_df.drop('Most people can be trusted, WVS round 1981-1984', axis=1, inplace=True)

# %%
df=in_df.drop('Most people can be trusted, WVS round 1989-1993', axis=1, inplace=True)

# %%
df=in_df.drop('Most people can be trusted, WVS round 1994-1998', axis=1, inplace=True)

# %%
df=in_df.drop('Most people can be trusted, WVS round 1999-2004', axis=1, inplace=True)

# %%
df=in_df.drop('Most people can be trusted, WVS round 2005-2009', axis=1, inplace=True)

# %%
df=in_df.drop('Most people can be trusted, WVS round 2010-2014', axis=1, inplace=True)

# %%
df=in_df.drop('gini of household income reported in Gallup, by wp5-year', axis=1, inplace=True)

# %%
df=in_df.drop('GINI index (World Bank estimate), average 2000-16', axis=1, inplace=True)

# %%
df=in_df.drop('Standard deviation/Mean of ladder by country-year', axis=1, inplace=True)

# %%
df=in_df.drop('Standard deviation of ladder by country-year', axis=1, inplace=True)

# %%
in_df.head()
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.517637         0.258195
# 1                   0.850035         0.583926         0.237092
# 2                   0.706766         0.618265         0.275324
# 3                   0.731109         0.611387         0.267175
# 4                   0.775620         0.710385         0.267919
#
#    Confidence in national government  Democratic Quality  Delivery Quality
# 0                           0.612072           -1.929690         -1.655084
# 1                           0.611545           -2.044093         -1.635025
# 2                           0.299357           -1.991810         -1.617176
# 3                           0.307386           -1.919018         -1.616221
# 4                           0.435440           -1.842996         -1.404078

# %%
pd.value_counts(in_df['Country name'])
# Out:
# Philippines                 13
# Uganda                      13
# Ukraine                     13
# China                       13
# Honduras                    13
# Dominican Republic          13
# India                       13
# Armenia                     13
# Georgia                     13
# South Africa                13
# Brazil                      13
# Bolivia                     13
# Sweden                      13
# Germany                     13
# Italy                       13
# Chile                       13
# Russia                      13
# Thailand                    13
# Nicaragua                   13
# Vietnam                     13
# Peru                        13
# Spain                       13
# Mexico                      13
# El Salvador                 13
# South Korea                 13
# France                      13
# United States               13
# Saudi Arabia                13
# Jordan                      13
# Turkey                      13
#                             ..
# Myanmar                      7
# Laos                         7
# Algeria                      7
# Ivory Coast                  7
# North Cyprus                 6
# Iceland                      6
# Jamaica                      5
# Comoros                      5
# Central African Republic     5
# Libya                        5
# Sudan                        5
# Trinidad and Tobago          5
# Mauritius                    5
# Qatar                        5
# Burundi                      5
# Angola                       4
# Djibouti                     4
# Namibia                      4
# South Sudan                  4
# Somaliland region            4
# Lesotho                      3
# Bhutan                       3
# Somalia                      3
# Belize                       2
# Gambia                       2
# Swaziland                    2
# Cuba                         1
# Oman                         1
# Suriname                     1
# Guyana                       1
# Name: Country name, Length: 165, dtype: int64

# %%
in_df.isnull().sum()
# Out:
# Country name                           0
# Year                                   0
# Life Ladder                            0
# Log GDP per capita                    28
# Social support                        13
# Healthy life expectancy at birth      28
# Freedom to make life choices          29
# Generosity                            82
# Perceptions of corruption             96
# Positive affect                       19
# Negative affect                       13
# Confidence in national government    174
# Democratic Quality                   146
# Delivery Quality                     145
# dtype: int64

# %%
in_df.shape
# Out:
# (1704, 14)

# %%
in_df['REGION']=''

# %%
in_df.head()
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.517637         0.258195
# 1                   0.850035         0.583926         0.237092
# 2                   0.706766         0.618265         0.275324
# 3                   0.731109         0.611387         0.267175
# 4                   0.775620         0.710385         0.267919
#
#    Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                           0.612072           -1.929690         -1.655084
# 1                           0.611545           -2.044093         -1.635025
# 2                           0.299357           -1.991810         -1.617176
# 3                           0.307386           -1.919018         -1.616221
# 4                           0.435440           -1.842996         -1.404078
#
#   REGION
# 0
# 1
# 2
# 3
# 4

# %%
in_df.dtypes
# Out:
# Country name                          object
# Year                                   int64
# Life Ladder                          float64
# Log GDP per capita                   float64
# Social support                       float64
# Healthy life expectancy at birth     float64
# Freedom to make life choices         float64
# Generosity                           float64
# Perceptions of corruption            float64
# Positive affect                      float64
# Negative affect                      float64
# Confidence in national government    float64
# Democratic Quality                   float64
# Delivery Quality                     float64
# REGION                                object
# dtype: object

# %%
in_df.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'REGION'],
#       dtype='object')

# %%
df=in_df.copy()

# %%
df=df.replace(['Argentina','Barbados','Belize','Bolivia','Brazil','Chile','Colombia','Ecuador','El Salvador','Costa Rica','Cuba','Dominican Republic','Guatemala','Guyana','Haiti','Honduras','Jamaica','Nicaragua','Panama','Peru','Paraguay','Uruguay','Venezuela','Mexico','Suriname','Trinidad and Tobago'], 'Latin America & Caribbean')

# %%
df=df.replace(['Afghanistan','Bangladesh','Bhutan','India','Maldives','Nepal','Pakistan','Sri Lanka'], 'South Asia')

# %%
df=df.replace(['Canada','United States'], 'North America')

# %%
df=df.replace(['Algeria','Benin','Botswana','Burkina Faso','Burundi','Cameroon','Central Africa Republic','Chad','Comoros','Congo (Brazzaville)','Congo (Kinshasa)','Ethiopia','Gabon','Gambia','Guinea','Ivory Coast','Kenya','Liberia','Madagascar','Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger','Nigeria','Rwanda','Senegal','Sierra Leone','South Africa','Swaziland','Tanzania','Togo','Uganda','Zambia','Zimbabwe','Central African Republic','Ghana','Angola','Somalia','Somaliland region','Sudan','Lesotho','South Sudan'], 'Sub-Saharan Africa')

# %%
df=df.replace(['Egypt','Iran','Israel','Jordan','Lebanon','Malta','Morocco','Palastinian Territories','Saudi Arabia','Tunisia','United Arab Emirates','Yemen','Bahrain','Djibouti','Qatar','Oman','Syria','Iraq','Kuwait','Palestinian Territories'], 'Middle East & North Africa')

# %%
df=df.replace(['Albania','Armenia','Austria','Azerbaijan','Belarus','Belgium','Bosnia and Herzegovina','Bulgaria','Croatia','Cyprus','Czech Republic','Denmark','Estonia','Finland','France','Georgia','Germany','Greece','Ireland','Italy','Kazakhstan','Kosovo','Kyrgyzstan','Latvia','Libya','Lithuania','Luxembourg','Macedonia','Moldova','Montenegro','Netherlands','North Cyprus','Norway','Portugal','Romania','Russia','Serbia','Slovakia','Slovenia','Spain','Sweden','Switzerland','Turkey','Turkmenistan','Ukraine','United Kingdom','Uzbekistan','Tajikistan','Hungary','Iceland','Poland'], 'Europe & Central Asia')

# %%
df=df.replace(['Australia','Austria','Cambodia','China','Hong Kong S.A.R. of China','Indonesia','Japan','Laos','Malaysia','Mongolia','Myanmar','Philippines','Thailand','Vietnam','Taiwan Province of China','New Zealand','South Korea','Singapore'], 'East Asia & Pacific')

# %%
df['Country name'].unique()
# Out:
# array(['South Asia', 'Europe & Central Asia', 'Sub-Saharan Africa',
#        'Latin America & Caribbean', 'East Asia & Pacific',
#        'Middle East & North Africa', 'North America'], dtype=object)

# %%
df[df['Social support'].isnull()][20:50]
# Out:
# Empty DataFrame
# Columns: [Country name, Year, Life Ladder, Log GDP per capita, Social support, Healthy life expectancy at birth, Freedom to make life choices, Generosity, Perceptions of corruption, Positive affect, Negative affect, Confidence in national government, Democratic Quality, Delivery Quality, REGION]
# Index: []

# %%
#fill missing values for age based on survival status, sex, and passenger class
#df['age'].fillna(df.groupby(['survived', 'sex', 'pclass'])['age'].transform('mean'), inplace=True)

df["Social support"].fillna(df.groupby(['Country name'])['Social support'].transform('mean'), inplace=True)

# %%
df[df['Social support'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Country name, Year, Life Ladder, Log GDP per capita, Social support, Healthy life expectancy at birth, Freedom to make life choices, Generosity, Perceptions of corruption, Positive affect, Negative affect, Confidence in national government, Democratic Quality, Delivery Quality, REGION]
# Index: []

# %%
df["Log GDP per capita"].fillna(df.groupby(['Country name'])['Log GDP per capita'].transform('mean'), inplace=True)

# %%
df["Healthy life expectancy at birth"].fillna(df.groupby(['Country name'])['Healthy life expectancy at birth'].transform('mean'), inplace=True)

# %%
df["Freedom to make life choices"].fillna(df.groupby(['Country name'])['Freedom to make life choices'].transform('mean'), inplace=True)

# %%
df["Generosity"].fillna(df.groupby(['Country name'])['Generosity'].transform('mean'), inplace=True)

# %%
df["Perceptions of corruption"].fillna(df.groupby(['Country name'])['Perceptions of corruption'].transform('mean'), inplace=True)

# %%
df["Positive affect"].fillna(df.groupby(['Country name'])['Positive affect'].transform('mean'), inplace=True)

# %%
df["Negative affect"].fillna(df.groupby(['Country name'])['Negative affect'].transform('mean'), inplace=True)

# %%
df["Confidence in national government"].fillna(df.groupby(['Country name'])['Confidence in national government'].transform('mean'), inplace=True)

# %%
df["Democratic Quality"].fillna(df.groupby(['Country name'])['Democratic Quality'].transform('mean'), inplace=True)

# %%
df["Delivery Quality"].fillna(df.groupby(['Country name'])['Delivery Quality'].transform('mean'), inplace=True)

# %%
df.head(1)
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0   South Asia  2008      3.72359             7.16869        0.450662
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.517637         0.258195
#
#    Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                           0.612072            -1.92969         -1.655084
#
#   REGION
# 0

# %%
df.isnull().sum()
# Out:
# Country name                         0
# Year                                 0
# Life_Ladder                          0
# GDP                                  0
# Social_support                       0
# Healthy_life                         0
# Freedom to make life choices         0
# Generosity                           0
# Perceptions of corruption            0
# Positive affect                      0
# Negative affect                      0
# Confidence in national government    0
# Democratic Quality                   0
# Delivery Quality                     0
# REGION                               0
# dtype: int64

# %%
df.sort_values('Country name')
# Out:
#              Country name  Year  Life_Ladder        GDP  Social_support  \
# 934   East Asia & Pacific  2012     5.914284  10.025297        0.841219
# 1388  East Asia & Pacific  2012     6.003287  10.366495        0.775397
# 1387  East Asia & Pacific  2011     6.946599  10.349087        0.809104
# 1386  East Asia & Pacific  2010     6.116024  10.320621        0.815517
# 1385  East Asia & Pacific  2009     5.647690  10.262659        0.810903
# 1470  East Asia & Pacific  2018     6.467005   9.632449        0.896459
# 1469  East Asia & Pacific  2017     6.359451   9.632449        0.891119
# 1468  East Asia & Pacific  2016     6.512851   9.632449        0.894989
# 1467  East Asia & Pacific  2015     6.450088   9.632449        0.885389
# 654   East Asia & Pacific  2006     4.946978   8.868148        0.770951
# 1335                           0.856166            0.707473          1.960737
# 1336                           0.843873            0.543806          2.078054
# 1337                           0.908558            0.574966          2.100870
# 1338                           0.930617            0.672655          2.071429
# 1339                           0.926998            0.708122          2.069170
# 1340                           0.892469            0.049643          0.444694
# 1331                           0.908408            0.505373          2.039838
# 935                            0.754481           -0.143944          0.605612
# 1390                           0.284104            0.394397          0.954132
# 1077                           0.626481            1.377388          1.856157
# 740                            0.221201            0.921506          1.311801
# 739                            0.240006            0.989995          1.287541
# 1394                           0.389084            0.049643          0.444694
# 1393                           0.358582            0.514762          0.957987
# 1657                           0.866249           -0.666042         -0.500649
# ...                                 ...                 ...               ...
# 964                            0.493745           -0.992718         -0.850889
# 965                            0.429032           -1.050638         -0.818570
# 927                            0.572985           -0.570682         -0.687820
# 926                            0.620333           -0.151015         -0.610421
# 925                            0.552534           -0.072648         -0.676236
# 924                            0.568602            0.013314         -0.640059
# 909                            0.649582           -0.792466         -0.731987
# 1431                           0.689549           -0.570682         -0.687820
# 1430                           0.353281           -0.897581         -0.541850
# 910                            0.350055           -0.709704         -0.805915
# 1428                           0.552376           -2.049856         -1.397204
# 1427                           0.552376           -2.017452         -1.405126
# 1426                           0.552376           -2.147116         -1.286357
# 1425                           0.552376           -2.195434         -1.298003
# 1424                           0.552376           -2.167385         -1.224691
# 911                            0.396854           -0.711675         -0.861626
# 907                            0.713698            0.036613         -0.351147
# 912                            0.509789           -0.528771         -0.893008
# 914                            0.490199           -0.300410         -0.896323
# 915                            0.541916           -0.337170         -0.934928
# 916                            0.442306           -0.570682         -0.687820
# 917                            0.691728           -0.066526         -0.532715
# 918                            0.763353           -0.089732         -0.413220
# 919                            0.829376           -0.047781         -0.359536
# 920                            0.419559           -0.159166         -0.424453
# 921                            0.471810           -0.104385         -0.468000
# 922                            0.641565           -0.192282         -0.483668
# 923                            0.619818            0.008398         -0.616410
# 913                            0.482405           -0.402996         -0.899808
# 1703                           0.550508           -0.570682         -0.687820
#
#      REGION
# 934
# 1388
# 1387
# 1386
# 1385
# 1470
# 1469
# 1468
# 1467
# 654
# 1389
# 1330
# 1332
# 1333
# 1334
# 1335
# 1336
# 1337
# 1338
# 1339
# 1340
# 1331
# 935
# 1390
# 1077
# 740
# 739
# 1394
# 1393
# 1657
# ...     ...
# 964
# 965
# 927
# 926
# 925
# 924
# 909
# 1431
# 1430
# 910
# 1428
# 1427
# 1426
# 1425
# 1424
# 911
# 907
# 912
# 914
# 915
# 916
# 917
# 918
# 919
# 920
# 921
# 922
# 923
# 913
# 1703
#
# [1704 rows x 15 columns]

# %%
df['Country name'].value_counts()
# Out:
# Europe & Central Asia         580
# Sub-Saharan Africa            380
# Latin America & Caribbean     259
# East Asia & Pacific           196
# Middle East & North Africa    185
# South Asia                     78
# North America                  26
# Name: Country name, dtype: int64

# %%
df['Life_Ladder'].min()
# Out:
# 2.6617181301116943

# %%
df['Life_Ladder'].max()
# Out:
# 8.01893424987793

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.corr()
# Out:
#                                        Year  Life_Ladder       GDP  \
# Year                               1.000000    -0.007075  0.047819
# Life_Ladder                       -0.007075     1.000000  0.773028
# GDP                                0.047819     0.773028  1.000000
# Social_support                    -0.046919     0.700716  0.663171
# Healthy_life                       0.120558     0.735489  0.831329
# Freedom to make life choices       0.164968     0.514959  0.343402
# Generosity                        -0.029550     0.192796 -0.002120
# Perceptions of corruption         -0.060243    -0.411735 -0.316784
# Positive affect                   -0.015647     0.538666  0.286630
# Negative affect                    0.189658    -0.276795 -0.149503
# Confidence in national government  0.002387    -0.095088 -0.177088
# Democratic Quality                -0.009346     0.609335  0.622318
# Delivery Quality                  -0.007244     0.697166  0.760534
#
#                                    Social_support  Healthy_life  \
# Year                                    -0.046919      0.120558
# Life_Ladder                              0.700716      0.735489
# GDP                                      0.663171      0.831329
# Social_support                           1.000000      0.604451
# Healthy_life                             0.604451      1.000000
# Freedom to make life choices             0.409640      0.366417
# Generosity                               0.071074      0.042598
# Perceptions of corruption               -0.210888     -0.311282
# Positive affect                          0.445375      0.317779
# Negative affect                         -0.374113     -0.116759
# Confidence in national government       -0.170941     -0.177417
# Democratic Quality                       0.540517      0.597315
# Delivery Quality                         0.549326      0.716568
#
#                                    Freedom to make life choices  Generosity  \
# Year                                                   0.164968   -0.029550
# Life_Ladder                                            0.514959    0.192796
# GDP                                                    0.343402   -0.002120
# Social_support                                         0.409640    0.071074
# Healthy_life                                           0.366417    0.042598
# Freedom to make life choices                           1.000000    0.337090
# Generosity                                             0.337090    1.000000
# Perceptions of corruption                             -0.486050   -0.288803
# Positive affect                                        0.611171    0.365602
# Negative affect                                       -0.273378   -0.114044
# Confidence in national government                      0.390764    0.265307
# Democratic Quality                                     0.432924    0.126061
# Delivery Quality                                       0.463127    0.201884
#
#                                    Perceptions of corruption  Positive affect  \
# Year                                               -0.060243        -0.015647
# Life_Ladder                                        -0.411735         0.538666
# GDP                                                -0.316784         0.286630
# Social_support                                     -0.210888         0.445375
# Healthy_life                                       -0.311282         0.317779
# Freedom to make life choices                       -0.486050         0.611171
# Generosity                                         -0.288803         0.365602
# Perceptions of corruption                           1.000000        -0.300400
# Positive affect                                    -0.300400         1.000000
# Negative affect                                     0.257973        -0.377276
# Confidence in national government                  -0.428633         0.146832
# Democratic Quality                                 -0.302742         0.371963
# Delivery Quality                                   -0.484517         0.347399
#
#                                    Negative affect  \
# Year                                      0.189658
# Life_Ladder                              -0.276795
# GDP                                      -0.149503
# Social_support                           -0.374113
# Healthy_life                             -0.116759
# Freedom to make life choices             -0.273378
# Generosity                               -0.114044
# Perceptions of corruption                 0.257973
# Positive affect                          -0.377276
# Negative affect                           1.000000
# Confidence in national government        -0.133005
# Democratic Quality                       -0.246216
# Delivery Quality                         -0.249663
#
#                                    Confidence in national government  \
# Year                                                        0.002387
# Life_Ladder                                                -0.095088
# GDP                                                        -0.177088
# Social_support                                             -0.170941
# Healthy_life                                               -0.177417
# Freedom to make life choices                                0.390764
# Generosity                                                  0.265307
# Perceptions of corruption                                  -0.428633
# Positive affect                                             0.146832
# Negative affect                                            -0.133005
# Confidence in national government                           1.000000
# Democratic Quality                                         -0.140631
# Delivery Quality                                           -0.049041
#
#                                    Democratic Quality  Delivery Quality
# Year                                        -0.009346         -0.007244
# Life_Ladder                                  0.609335          0.697166
# GDP                                          0.622318          0.760534
# Social_support                               0.540517          0.549326
# Healthy_life                                 0.597315          0.716568
# Freedom to make life choices                 0.432924          0.463127
# Generosity                                   0.126061          0.201884
# Perceptions of corruption                   -0.302742         -0.484517
# Positive affect                              0.371963          0.347399
# Negative affect                             -0.246216         -0.249663
# Confidence in national government           -0.140631         -0.049041
# Democratic Quality                           1.000000          0.860390
# Delivery Quality                             0.860390          1.000000

# %%
df=df.rename(columns={"Life Ladder": "Life_Ladder", "Log GDP per capita": "GDP","Social support":"Social_support","Healthy life expectancy at birth":"Healthy_life"})

# %%
f=df.rename(columns={"Freedom to make life choices":"Freedom"})

# %%
f.head(1)
# Out:
#   Country name  Year  Life_Ladder      GDP  Social_support  Healthy_life  \
# 0   South Asia  2008      3.72359  7.16869        0.450662     50.799999
#
#     Freedom  Generosity  Perceptions of corruption  Positive affect  \
# 0  0.718114    0.177889                   0.881686         0.517637
#
#    Negative affect  Confidence in national government  Democratic Quality  \
# 0         0.258195                           0.612072            -1.92969
#
#    Delivery Quality REGION
# 0         -1.655084

# %%
writer = pd.ExcelWriter('happiness_final.xlsx', engine='xlsxwriter')
condf.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
no_r=f.drop('Country name', axis=1)

# %%
#no_r=f.drop('Democratic Quality', axis=1)

# %%
#no_r=f.drop('REGION', axis=1)

# %%
#no_r=f.drop('Delivery Quality', axis=1)

# %%
no_r.head(1)
# Out:
#    Year  Life_Ladder      GDP  Social_support  Healthy_life   Freedom  \
# 0  2008      3.72359  7.16869        0.450662     50.799999  0.718114
#
#    Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 0    0.177889                   0.881686         0.517637         0.258195
#
#    Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                           0.612072            -1.92969         -1.655084
#
#   REGION
# 0

# %%
p=no_r.drop('Democratic Quality', axis=1)

# %%
q=p.drop('Delivery Quality', axis=1)

# %%
import statsmodels.formula.api as smf

# %%
#result = smf.ols(' Life_Ladder~ Generosity + Freedom', data=df).fit()

# %%
#result.summary()

# %%
from sklearn.linear_model import LinearRegression

# %%
q.describe()
# Out:
#               Year  Life_Ladder          GDP  Social_support  Healthy_life  \
# count  1704.000000  1704.000000  1704.000000     1704.000000   1704.000000
# mean   2012.332160     5.437155     9.222513        0.810563     63.114473
# std       3.688072     1.121149     1.181665        0.118857      7.557059
# min    2005.000000     2.661718     6.457201        0.290184     32.299999
# 25%    2009.000000     4.610970     8.300626        0.748136     58.315000
# 50%    2012.000000     5.339557     9.412297        0.832166     65.000000
# 75%    2015.000000     6.273522    10.172009        0.904344     68.204998
# max    2018.000000     8.018934    11.770276        0.987343     76.800003
#
#            Freedom   Generosity  Perceptions of corruption  Positive affect  \
# count  1704.000000  1704.000000                1704.000000      1704.000000
# mean      0.734097     0.000154                   0.750543         0.708817
# std       0.143118     0.160011                   0.180932         0.107608
# min       0.257534    -0.336385                   0.035198         0.362498
# 25%       0.640215    -0.107994                   0.697359         0.622920
# 50%       0.752051    -0.022296                   0.796774         0.716836
# 75%       0.846841     0.090806                   0.869763         0.799564
# max       0.985178     0.677743                   0.983276         0.943621
#
#        Negative affect  Confidence in national government
# count      1704.000000                        1704.000000
# mean          0.266002                           0.482861
# std           0.084566                           0.182831
# min           0.083426                           0.068769
# 25%           0.205834                           0.348712
# 50%           0.254965                           0.479327
# 75%           0.316504                           0.597703
# max           0.704590                           0.993604

# %%
q.isnull().sum()
# Out:
# Year                                 0
# Life_Ladder                          0
# GDP                                  0
# Social_support                       0
# Healthy_life                         0
# Freedom                              0
# Generosity                           0
# Perceptions of corruption            0
# Positive affect                      0
# Negative affect                      0
# Confidence in national government    0
# REGION                               0
# dtype: int64

# %%
q.dtypes
# Out:
# Year                                   int64
# Life_Ladder                          float64
# GDP                                  float64
# Social_support                       float64
# Healthy_life                         float64
# Freedom                              float64
# Generosity                           float64
# Perceptions of corruption            float64
# Positive affect                      float64
# Negative affect                      float64
# Confidence in national government    float64
# REGION                                object
# dtype: object

# %%
q.drop('REGION',axis=1 ,inplace=True)

# %%
r = np.nan_to_num(q)

# %%
condf =q.apply(pd.to_numeric)

# %%
condf.dtypes
# Out:
# Year                                   int64
# Life_Ladder                          float64
# GDP                                  float64
# Social_support                       float64
# Healthy_life                         float64
# Freedom                              float64
# Generosity                           float64
# Perceptions of corruption            float64
# Positive affect                      float64
# Negative affect                      float64
# Confidence in national government    float64
# dtype: object

# %%
X = condf.drop('Life_Ladder', axis = 1)
lm = LinearRegression()

# %%
lm.fit(X,condf['Life_Ladder'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Estimated intercept coefficient:', lm.intercept_)
# Out:
# Estimated intercept coefficient: 33.941366298337066

# %%
print('Number of coefficients:', len(lm.coef_))
# Out:
# Number of coefficients: 10

# %%
pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['features', 'estimatedCoefficients'])
# Out:
#                             features  estimatedCoefficients
# 0                               Year              -0.017749
# 1                                GDP               0.349712
# 2                     Social_support               1.603095
# 3                       Healthy_life               0.025007
# 4                            Freedom               0.870771
# 5                         Generosity               0.403111
# 6          Perceptions of corruption              -0.810611
# 7                    Positive affect               1.994421
# 8                    Negative affect               0.006098
# 9  Confidence in national government              -0.696227

# %%
lm.predict(X)[0:5]
# Out:
# array([3.391014  , 3.73689071, 4.03349427, 3.89025052, 4.04725951])

# %%
lm.score(X, condf['Life_Ladder'])
# Out:
# 0.7643810196101057

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(condf['Life_Ladder'], lm.predict(X))
plt.xlabel("life_ladder")
plt.ylabel("Predicted Ladder")
plt.title("score vs Predicted score")
plt.figure(figsize=(10,6))
plt.show()

# %%
import sklearn #library for predictive modeling

# %matplotlib inline

# %%
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
    X, condf.Life_Ladder, test_size=0.33, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1141, 10)
# (563, 10)
# (1141,)
# (563,)

# %%
lm.fit(X_train, Y_train)

#predictions for training and test data
pred_train = lm.predict(X_train)
pred_test = lm.predict(X_test)

# %%
print(lm.score(X_train, Y_train))
print(lm.score(X_test, Y_test))
# Out:
# 0.7682454300460281
# 0.7539645415440602

# %%
writer = pd.ExcelWriter('happiness_final.xlsx', engine='xlsxwriter')
condf.to_excel(writer, sheet_name='Sheet1')
writer.save()
